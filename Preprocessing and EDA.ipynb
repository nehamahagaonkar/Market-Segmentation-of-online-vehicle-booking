# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\nehap\OneDrive\Desktop\market segmentation of online vehicle booking\online_vehicle_bookings_india.csv")
df.head()
# Out:
#    Booking_ID User_ID Vehicle_Type   Pickup_Location      Drop_Location  \
# 0        1001   U9677    Hatchback    Chennai Center     Mumbai Station
# 1        1002   U6729          SUV       Pune Center    Kolkata Station
# 2        1003   U7281        Sedan     Mumbai Center      Delhi Station
# 3        1004   U5473          SUV       Pune Center  Bangalore Station
# 4        1005   U2312    Hatchback  Hyderabad Center      Delhi Station
#
#   Booking_Date Booking_Time  Distance_km    Fare Payment_Mode Driver_ID  \
# 0   06-06-2024        11:23          8.9  180.42          UPI      D305
# 1   01-06-2024        03:43         17.1  310.66         Cash      D680
# 2   03-06-2024        12:34         22.1  506.87          UPI      D453
# 3   05-06-2024        09:49          3.8   90.57         Cash      D152
# 4   05-06-2024        18:26         27.6  553.17         Cash      D366
#
#       Status
# 0  Completed
# 1  Completed
# 2    Pending
# 3  Cancelled
# 4  Cancelled

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')
sns.set_palette('coolwarm')

for i in df.columns:
    if df[i].dtype != 'O':
        sns.boxplot(x = df[i])
        plt.title('Distribution of '+i)
        plt.show()
